# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/freelancing/ehtisham work/Index prediction/'

# %%
df=pd.read_excel(path+"data.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0      D/M/Y     H:M:S    CO       CH4    H2S  SPO2
# 0           0 2020-05-05  10:25:01  5.37  10496.41  15.45  98.0
# 1           1 2020-05-05  11:25:02  5.13   9721.47   5.73  98.0
# 2           2 2020-05-05  10:25:26  4.89   8707.83   5.17  98.0
# 3           3 2020-05-05  10:25:26  4.71   8045.35   4.67  98.0
# 4           4 2020-05-05  10:25:26  4.35   7040.90   4.25  98.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# D/M/Y             0
# H:M:S             0
# CO                0
# CH4               0
# H2S           50640
# SPO2          25233
# dtype: int64

# %%
df.shape
# Out:
# (53566, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53566 entries, 0 to 53565
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53566 non-null  int64
#  1   D/M/Y       53566 non-null  datetime64[ns]
#  2   H:M:S       53566 non-null  object
#  3   CO          53566 non-null  float64
#  4   CH4         53566 non-null  float64
#  5   H2S         2926 non-null   float64
#  6   SPO2        28333 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 2.9+ MB

# %%
df['D/M/Y'] = df['D/M/Y'].dt.strftime('%Y-%m-%d')

# %%
def check_type(data):
    if type(data) is str:
        return data
    else:
        return data.strftime("%H:%M:%S")

# %%
df['H:M:S'] = df['H:M:S'].apply(lambda x: check_type(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53566 entries, 0 to 53565
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53566 non-null  int64
#  1   D/M/Y       53566 non-null  object
#  2   H:M:S       53566 non-null  object
#  3   CO          53566 non-null  float64
#  4   CH4         53566 non-null  float64
#  5   H2S         2926 non-null   float64
#  6   SPO2        28333 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.9+ MB

# %%
df.head()
# Out:
#    Unnamed: 0       D/M/Y     H:M:S    CO       CH4    H2S  SPO2
# 0           0  2020-05-05  10:25:01  5.37  10496.41  15.45  98.0
# 1           1  2020-05-05  11:25:02  5.13   9721.47   5.73  98.0
# 2           2  2020-05-05  10:25:26  4.89   8707.83   5.17  98.0
# 3           3  2020-05-05  10:25:26  4.71   8045.35   4.67  98.0
# 4           4  2020-05-05  10:25:26  4.35   7040.90   4.25  98.0

# %%
t=df.iloc[1,2]

# %%
type(t)
# Out:
# str

# %%
df['DateTime']=df['D/M/Y']+' '+df["H:M:S"]

# %%
df.head()
# Out:
#    Unnamed: 0       D/M/Y     H:M:S    CO       CH4    H2S  SPO2  \
# 0           0  2020-05-05  10:25:01  5.37  10496.41  15.45  98.0
# 1           1  2020-05-05  11:25:02  5.13   9721.47   5.73  98.0
# 2           2  2020-05-05  10:25:26  4.89   8707.83   5.17  98.0
# 3           3  2020-05-05  10:25:26  4.71   8045.35   4.67  98.0
# 4           4  2020-05-05  10:25:26  4.35   7040.90   4.25  98.0
#
#               DateTime
# 0  2020-05-05 10:25:01
# 1  2020-05-05 11:25:02
# 2  2020-05-05 10:25:26
# 3  2020-05-05 10:25:26
# 4  2020-05-05 10:25:26

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'D/M/Y', 'H:M:S', 'CO', 'CH4', 'H2S', 'SPO2', 'DateTime'], dtype='object')

# %%
df.drop(['Unnamed: 0', 'D/M/Y', 'H:M:S','CO', 'H2S', 'CH4'],inplace=True,axis=1)

# %%
df
# Out:
#        SPO2             DateTime
# 0      98.0  2020-05-05 10:25:01
# 1      98.0  2020-05-05 11:25:02
# 2      98.0  2020-05-05 10:25:26
# 3      98.0  2020-05-05 10:25:26
# 4      98.0  2020-05-05 10:25:26
# ...     ...                  ...
# 53561  98.0  2020-05-05 18:9:58
# 53562  98.0  2020-05-05 18:9:59
# 53563  98.0  2020-05-05 18:09:06
# 53564  97.0  2020-05-05 18:09:07
# 53565  98.0  2020-05-05 18:09:09
#
# [53566 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# SPO2        25233
# DateTime        0
# dtype: int64

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'],errors='coerce', format='%Y-%m-%d %H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53566 entries, 0 to 53565
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SPO2      28333 non-null  float64
#  1   DateTime  53563 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 837.1 KB

# %%
df.head()
# Out:
#    SPO2            DateTime
# 0  98.0 2020-05-05 10:25:01
# 1  98.0 2020-05-05 11:25:02
# 2  98.0 2020-05-05 10:25:26
# 3  98.0 2020-05-05 10:25:26
# 4  98.0 2020-05-05 10:25:26

# %%
df.isnull().sum()
# Out:
# SPO2        25233
# DateTime        3
# dtype: int64

# %%
plt.plot(df.SPO2)

# %%
plt.hist(df.SPO2)
# Out:
# (array([7.0000e+00, 4.0000e+01, 0.0000e+00, 9.9000e+01, 4.4000e+01,
#         1.2000e+01, 2.2400e+02, 4.9200e+02, 1.6390e+03, 2.5776e+04]),
#  array([88. , 89.1, 90.2, 91.3, 92.4, 93.5, 94.6, 95.7, 96.8, 97.9, 99. ]),
#  <a list of 10 Patch objects>)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# SPO2        0
# DateTime    0
# dtype: int64

# %%
df.shape
# Out:
# (28330, 2)

# %%
min(df['SPO2'])
# Out:
# 88.0

# %%
max(df['SPO2'])
# Out:
# 99.0

# %%
np.std(df['SPO2'])
# Out:
# 0.915784425534899

# %%
np.average(df['SPO2'])
# Out:
# 98.26166607836215

# %%
df1=df

# %%
df=df1

# %%
df.head()
# Out:
#    SPO2            DateTime
# 0  98.0 2020-05-05 10:25:01
# 1  98.0 2020-05-05 11:25:02
# 2  98.0 2020-05-05 10:25:26
# 3  98.0 2020-05-05 10:25:26
# 4  98.0 2020-05-05 10:25:26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28330 entries, 0 to 53565
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SPO2      28330 non-null  float64
#  1   DateTime  28330 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 664.0 KB

# %%
# df['CH4'][df['CH4']>5000]=5000

# %%
df.head()
# Out:
#    SPO2            DateTime
# 0  98.0 2020-05-05 10:25:01
# 1  98.0 2020-05-05 11:25:02
# 2  98.0 2020-05-05 10:25:26
# 3  98.0 2020-05-05 10:25:26
# 4  98.0 2020-05-05 10:25:26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28330 entries, 0 to 53565
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SPO2      28330 non-null  float64
#  1   DateTime  28330 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 664.0 KB

# %%
plt.grid()
plt.plot(df.SPO2,marker="o", markersize=2, markeredgecolor="red",
markerfacecolor="green")
plt.show()

# %%
sns.distplot(df.SPO2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.countplot(ax=ax, data=df, x='SPO2')

# %%
sns.violinplot(df.SPO2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(30,10))
plt.grid()
plt.plot(df.SPO2,marker="o", markersize=2,
markerfacecolor="green")
plt.show()

# %%
df.head()
# Out:
#    SPO2            DateTime
# 0  98.0 2020-05-05 10:25:01
# 1  98.0 2020-05-05 11:25:02
# 2  98.0 2020-05-05 10:25:26
# 3  98.0 2020-05-05 10:25:26
# 4  98.0 2020-05-05 10:25:26

# %%
df.tail()
# Out:
#        SPO2            DateTime
# 53561  98.0 2020-05-05 18:09:58
# 53562  98.0 2020-05-05 18:09:59
# 53563  98.0 2020-05-05 18:09:06
# 53564  97.0 2020-05-05 18:09:07
# 53565  98.0 2020-05-05 18:09:09

# %%
df.DateTime.values
# Out:
# array(['2020-05-05T10:25:01.000000000', '2020-05-05T11:25:02.000000000',
#        '2020-05-05T10:25:26.000000000', ...,
#        '2020-05-05T18:09:06.000000000', '2020-05-05T18:09:07.000000000',
#        '2020-05-05T18:09:09.000000000'], dtype='datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28330 entries, 0 to 53565
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SPO2      28330 non-null  float64
#  1   DateTime  28330 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.7 MB

# %%
df = df.sort_values('DateTime')

# %%
plt.figure(figsize = (30,9))
plt.plot(df["DateTime"],df['SPO2'])
# plt.xticks(range(0,df.shape[0],5),df['DateTime'].loc[::5],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
df.head()
# Out:
#         CH4            DateTime
# 0   5000.00 2020-05-05 10:25:01
# 24  2453.22 2020-05-05 10:25:26
# 25  2382.70 2020-05-05 10:25:26
# 26  2337.38 2020-05-05 10:25:26
# 27  2277.23 2020-05-05 10:25:26

# %%
scale=MinMaxScaler(feature_range = (0, 1))
df[['SPO2']]=scale.fit_transform(df[['SPO2']])

# %%
plt.figure(figsize=(10,10))
plt.grid()
plt.plot(df.SPO2,marker="o", markersize=2,
markerfacecolor="green")
plt.show()

# %%
train_size = int(len(df) * 0.85)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(train), len(test))
# Out:
# 24080 4250

# %%
df.head()
# Out:
#          CH4            DateTime
# 0   1.000000 2020-05-05 10:25:01
# 24  0.490644 2020-05-05 10:25:26
# 25  0.476540 2020-05-05 10:25:26
# 26  0.467476 2020-05-05 10:25:26
# 27  0.455446 2020-05-05 10:25:26

# %%
from sklearn.preprocessing import RobustScaler

f_columns = ['DateTime']

f_transformer = RobustScaler()
cnt_transformer = RobustScaler()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())
cnt_transformer = cnt_transformer.fit(train[['SPO2']])

train.loc[:, f_columns] = f_transformer.transform(train[f_columns].to_numpy())
train['SPO2'] = cnt_transformer.transform(train[['SPO2']])

test.loc[:, f_columns] = f_transformer.transform(test[f_columns].to_numpy())
test['SPO2'] = cnt_transformer.transform(test[['SPO2']])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 10

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train.SPO2, time_steps)
X_test, y_test = create_dataset(test, test.SPO2, time_steps)

print(X_train.shape, y_train.shape)
# Out:
# (24070, 10, 2) (24070,)

# %%
tf.__version__
# Out:
# '2.8.0'

# %% [markdown]
# # LSTM

# %%
#initialisizng the model 
model= keras.Sequential()

#First Input layer and LSTM layer with 0.2% dropout
model.add(keras.layers.LSTM(units=50,return_sequences=True,kernel_initializer='glorot_uniform',input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(keras.layers.Dropout(0.2))

# Where:
#     return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence.

# Second LSTM layer with 0.2% dropout
model.add(keras.layers.LSTM(units=50,kernel_initializer='glorot_uniform',return_sequences=True))
model.add(keras.layers.Dropout(0.2))

#Third LSTM layer with 0.2% dropout
model.add(keras.layers.LSTM(units=50,kernel_initializer='glorot_uniform',return_sequences=True))
model.add(keras.layers.Dropout(0.2))

#Fourth LSTM layer with 0.2% dropout, we wont use return sequence true in last layers as we dont want to previous output
model.add(keras.layers.LSTM(units=50,kernel_initializer='glorot_uniform'))
model.add(keras.layers.Dropout(0.2))
#Output layer , we wont pass any activation as its continous value model
model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
history = model.fit(
    X_train, y_train, 
    epochs=200, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/200
# 677/677 [==============================] - 17s 11ms/step - loss: 0.3225 - val_loss: 0.2700
# Epoch 2/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.5357 - val_loss: 0.0409
# Epoch 3/200
# 677/677 [==============================] - 9s 13ms/step - loss: 0.5248 - val_loss: 0.0148
# Epoch 4/200
# 677/677 [==============================] - 9s 13ms/step - loss: 0.3353 - val_loss: 0.0033
# Epoch 5/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.2979 - val_loss: 0.0122
# Epoch 6/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.2667 - val_loss: 0.0021
# Epoch 7/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.2538 - val_loss: 0.0036
# Epoch 8/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.3006 - val_loss: 0.0499
# Epoch 9/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.2814 - val_loss: 0.0040
# Epoch 10/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.2196 - val_loss: 0.0019
# Epoch 11/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.1970 - val_loss: 0.0038
# Epoch 12/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.1673 - val_loss: 0.0012
# Epoch 13/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.1233 - val_loss: 0.0010
# Epoch 14/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.1220 - val_loss: 0.0065
# Epoch 15/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0775 - val_loss: 0.0012
# Epoch 16/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0656 - val_loss: 0.0018
# Epoch 17/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0575 - val_loss: 7.5535e-04
# Epoch 18/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0397 - val_loss: 7.3055e-04
# Epoch 19/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0415 - val_loss: 0.0017
# Epoch 20/200
# 677/677 [==============================] - 9s 14ms/step - loss: 0.0642 - val_loss: 0.0026
# Epoch 21/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0429 - val_loss: 0.0011
# Epoch 22/200
# 677/677 [==============================] - 8s 12ms/step - loss: 0.0412 - val_loss: 7.2388e-04
# Epoch 23/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0360 - val_loss: 6.2195e-04
# Epoch 24/200
# 677/677 [==============================] - 9s 13ms/step - loss: 0.0334 - val_loss: 0.0013
# Epoch 25/200
# 677/677 [==============================] - 8s 11ms/step - loss: 0.0417 - val_loss: 0.0011
# Epoch 26/200
# 677/677 [==============================] - 9s 14ms/step - loss: 0.0372 - val_loss: 6.4958e-04
# Epoch 27/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0332 - val_loss: 0.0032
# Epoch 28/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0418 - val_loss: 0.0015
# Epoch 29/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0455 - val_loss: 6.0610e-04
# Epoch 30/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0343 - val_loss: 6.8509e-04
# Epoch 31/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0293 - val_loss: 5.3662e-04
# Epoch 32/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0282 - val_loss: 9.9515e-04
# Epoch 33/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0340 - val_loss: 0.0011
# Epoch 34/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0296 - val_loss: 0.0018
# Epoch 35/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0706 - val_loss: 9.6579e-04
# Epoch 36/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0426 - val_loss: 0.0023
# Epoch 37/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0511 - val_loss: 6.3295e-04
# Epoch 38/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0321 - val_loss: 7.8516e-04
# Epoch 39/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0278 - val_loss: 6.4536e-04
# Epoch 40/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0274 - val_loss: 0.0012
# Epoch 41/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0301 - val_loss: 9.7982e-04
# Epoch 42/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0374 - val_loss: 5.5974e-04
# Epoch 43/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0372 - val_loss: 9.3369e-04
# Epoch 44/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0446 - val_loss: 8.2901e-04
# Epoch 45/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0321 - val_loss: 0.0011
# Epoch 46/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0313 - val_loss: 9.5965e-04
# Epoch 47/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0285 - val_loss: 8.3202e-04
# Epoch 48/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0321 - val_loss: 7.6448e-04
# Epoch 49/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0289 - val_loss: 0.0012
# Epoch 50/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0303 - val_loss: 6.8644e-04
# Epoch 51/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0299 - val_loss: 8.7578e-04
# Epoch 52/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0306 - val_loss: 7.0058e-04
# Epoch 53/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0296 - val_loss: 0.0021
# Epoch 54/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0299 - val_loss: 0.0020
# Epoch 55/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0285 - val_loss: 7.7731e-04
# Epoch 56/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0322 - val_loss: 6.8685e-04
# Epoch 57/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0251 - val_loss: 0.0016
# Epoch 58/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0294 - val_loss: 0.0013
# Epoch 59/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0295 - val_loss: 0.0017
# Epoch 60/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0235 - val_loss: 9.2704e-04
# Epoch 61/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0253 - val_loss: 0.0016
# Epoch 62/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0355 - val_loss: 9.3548e-04
# Epoch 63/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0301 - val_loss: 6.7899e-04
# Epoch 64/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0340 - val_loss: 8.7319e-04
# Epoch 65/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0350 - val_loss: 0.0011
# Epoch 66/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0354 - val_loss: 0.0013
# Epoch 67/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0273 - val_loss: 8.9526e-04
# Epoch 68/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0302 - val_loss: 8.4929e-04
# Epoch 69/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0342 - val_loss: 9.4472e-04
# Epoch 70/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0275 - val_loss: 0.0014
# Epoch 71/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0241 - val_loss: 0.0012
# Epoch 72/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0240 - val_loss: 0.0014
# Epoch 73/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0243 - val_loss: 8.1025e-04
# Epoch 74/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0332 - val_loss: 8.4439e-04
# Epoch 75/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0527 - val_loss: 0.0013
# Epoch 76/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0318 - val_loss: 5.3748e-04
# Epoch 77/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0315 - val_loss: 0.0010
# Epoch 78/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0306 - val_loss: 7.4736e-04
# Epoch 79/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0353 - val_loss: 0.0017
# Epoch 80/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0408 - val_loss: 7.7134e-04
# Epoch 81/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0343 - val_loss: 0.0011
# Epoch 82/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0387 - val_loss: 8.1100e-04
# Epoch 83/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0363 - val_loss: 0.0014
# Epoch 84/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0306 - val_loss: 0.0011
# Epoch 85/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0375 - val_loss: 0.0016
# Epoch 86/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0489 - val_loss: 6.6709e-04
# Epoch 87/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0292 - val_loss: 0.0010
# Epoch 88/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0376 - val_loss: 0.0018
# Epoch 89/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0392 - val_loss: 0.0016
# Epoch 90/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0565 - val_loss: 0.0015
# Epoch 91/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0385 - val_loss: 9.7794e-04
# Epoch 92/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0385 - val_loss: 0.0014
# Epoch 93/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0379 - val_loss: 0.0012
# Epoch 94/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0451 - val_loss: 6.9912e-04
# Epoch 95/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0270 - val_loss: 0.0014
# Epoch 96/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0283 - val_loss: 0.0013
# Epoch 97/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0250 - val_loss: 0.0049
# Epoch 98/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0299 - val_loss: 7.4951e-04
# Epoch 99/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0307 - val_loss: 0.0014
# Epoch 100/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0256 - val_loss: 5.1845e-04
# Epoch 101/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0265 - val_loss: 0.0012
# Epoch 102/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0226 - val_loss: 0.0017
# Epoch 103/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0249 - val_loss: 0.0010
# Epoch 104/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0306 - val_loss: 9.3039e-04
# Epoch 105/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0329 - val_loss: 0.0019
# Epoch 106/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0263 - val_loss: 8.2926e-04
# Epoch 107/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0236 - val_loss: 9.7359e-04
# Epoch 108/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0229 - val_loss: 0.0011
# Epoch 109/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0237 - val_loss: 0.0012
# Epoch 110/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0277 - val_loss: 7.1358e-04
# Epoch 111/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0351 - val_loss: 8.3892e-04
# Epoch 112/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0333 - val_loss: 0.0010
# Epoch 113/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0303 - val_loss: 0.0010
# Epoch 114/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0421 - val_loss: 7.3152e-04
# Epoch 115/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0391 - val_loss: 0.0013
# Epoch 116/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0526 - val_loss: 6.6331e-04
# Epoch 117/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0326 - val_loss: 0.0015
# Epoch 118/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0257 - val_loss: 0.0025
# Epoch 119/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0261 - val_loss: 6.8173e-04
# Epoch 120/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0244 - val_loss: 0.0012
# Epoch 121/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0232 - val_loss: 0.0017
# Epoch 122/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0225 - val_loss: 0.0016
# Epoch 123/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0245 - val_loss: 0.0012
# Epoch 124/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0209 - val_loss: 0.0014
# Epoch 125/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0234 - val_loss: 0.0014
# Epoch 126/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0257 - val_loss: 0.0011
# Epoch 127/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0251 - val_loss: 0.0016
# Epoch 128/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0221 - val_loss: 7.6976e-04
# Epoch 129/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0205 - val_loss: 9.5489e-04
# Epoch 130/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0212 - val_loss: 9.3964e-04
# Epoch 131/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0205 - val_loss: 0.0011
# Epoch 132/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0223 - val_loss: 0.0012
# Epoch 133/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0226 - val_loss: 0.0010
# Epoch 134/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0215 - val_loss: 0.0018
# Epoch 135/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0210 - val_loss: 0.0010
# Epoch 136/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0221 - val_loss: 9.7945e-04
# Epoch 137/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0243 - val_loss: 0.0012
# Epoch 138/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0211 - val_loss: 0.0013
# Epoch 139/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0216 - val_loss: 0.0012
# Epoch 140/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0283 - val_loss: 7.6806e-04
# Epoch 141/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0558 - val_loss: 0.0013
# Epoch 142/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0535 - val_loss: 0.0012
# Epoch 143/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0286 - val_loss: 8.8786e-04
# Epoch 144/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0246 - val_loss: 6.7787e-04
# Epoch 145/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0229 - val_loss: 9.6369e-04
# Epoch 146/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0215 - val_loss: 0.0010
# Epoch 147/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0201 - val_loss: 0.0014
# Epoch 148/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0199 - val_loss: 0.0017
# Epoch 149/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0212 - val_loss: 9.2947e-04
# Epoch 150/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0232 - val_loss: 8.7376e-04
# Epoch 151/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0227 - val_loss: 7.2847e-04
# Epoch 152/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0217 - val_loss: 0.0012
# Epoch 153/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0210 - val_loss: 9.0695e-04
# Epoch 154/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0212 - val_loss: 0.0014
# Epoch 155/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0237 - val_loss: 7.4724e-04
# Epoch 156/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0381 - val_loss: 7.9110e-04
# Epoch 157/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0426 - val_loss: 7.7640e-04
# Epoch 158/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0453 - val_loss: 0.0010
# Epoch 159/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0252 - val_loss: 5.8439e-04
# Epoch 160/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0219 - val_loss: 6.9576e-04
# Epoch 161/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0214 - val_loss: 0.0015
# Epoch 162/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0223 - val_loss: 5.8937e-04
# Epoch 163/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0210 - val_loss: 9.4174e-04
# Epoch 164/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0203 - val_loss: 0.0013
# Epoch 165/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0201 - val_loss: 0.0011
# Epoch 166/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0260 - val_loss: 8.7580e-04
# Epoch 167/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0251 - val_loss: 7.5710e-04
# Epoch 168/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0219 - val_loss: 0.0015
# Epoch 169/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0211 - val_loss: 0.0011
# Epoch 170/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0229 - val_loss: 8.8518e-04
# Epoch 171/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0207 - val_loss: 0.0012
# Epoch 172/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0197 - val_loss: 0.0014
# Epoch 173/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0214 - val_loss: 0.0010
# Epoch 174/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0211 - val_loss: 0.0010
# Epoch 175/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0214 - val_loss: 7.7524e-04
# Epoch 176/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0209 - val_loss: 8.7449e-04
# Epoch 177/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0204 - val_loss: 0.0012
# Epoch 178/200
# 677/677 [==============================] - 6s 10ms/step - loss: 0.0209 - val_loss: 8.3037e-04
# Epoch 179/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0266 - val_loss: 9.2042e-04
# Epoch 180/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0210 - val_loss: 9.8308e-04
# Epoch 181/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0213 - val_loss: 0.0012
# Epoch 182/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0268 - val_loss: 0.0017
# Epoch 183/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0299 - val_loss: 0.0013
# Epoch 184/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0348 - val_loss: 5.4891e-04
# Epoch 185/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0266 - val_loss: 8.6732e-04
# Epoch 186/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0239 - val_loss: 0.0013
# Epoch 187/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0252 - val_loss: 0.0011
# Epoch 188/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0251 - val_loss: 9.8028e-04
# Epoch 189/200
# 677/677 [==============================] - 7s 10ms/step - loss: 0.0265 - val_loss: 9.8605e-04
# Epoch 190/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0300 - val_loss: 7.1783e-04
# Epoch 191/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0219 - val_loss: 0.0010
# Epoch 192/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0218 - val_loss: 0.0013
# Epoch 193/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0263 - val_loss: 0.0012
# Epoch 194/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0258 - val_loss: 0.0012
# Epoch 195/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0222 - val_loss: 0.0013
# Epoch 196/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0207 - val_loss: 0.0010
# Epoch 197/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0204 - val_loss: 8.7272e-04
# Epoch 198/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0214 - val_loss: 0.0011
# Epoch 199/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0192 - val_loss: 8.3996e-04
# Epoch 200/200
# 677/677 [==============================] - 6s 9ms/step - loss: 0.0202 - val_loss: 9.6909e-04

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
y_pred = model.predict(X_test)
y_train_inv = cnt_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv = cnt_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = cnt_transformer.inverse_transform(y_pred)
plt.figure(figsize=(20,8))
plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('SPO2')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.figure(figsize=(20,8))
plt.plot(y_test_inv.flatten(), marker='.', label="true")
plt.plot(y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('SPO2')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
model.save(path+'models/SPO2/SPO2_lstm.h5')

# %%
import pickle
output = open(path+'encoders/SPO2_encoder.pkl', 'wb')
pickle.dump(scale, output)
output.close()

# %% [markdown]
# # ARIME Model

# %%
# !pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels) (1.15.0)

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller
from scipy.ndimage.interpolation import shift
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df.head()
# Out:
#         SPO2            DateTime
# 0   0.909091 2020-05-05 10:25:01
# 24  0.909091 2020-05-05 10:25:26
# 25  0.909091 2020-05-05 10:25:26
# 26  0.909091 2020-05-05 10:25:26
# 27  0.909091 2020-05-05 10:25:26

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(df['SPO2'].values, label = "CO data")
plt.legend()

# %%
def isSeriesStationary(series):
    pValue = adfuller(series)[1]
    if pValue > 0.05:
        return False
    else:
        return True

# %%
def isSeriesStationaryAvg(series, delta = 2):
    split = int(len(series)/2)
    split1, split2 = series[:split], series[split:]
    avg1, avg2 = split1.mean(), split2.mean()
    var1, var2 = split1.var(), split2.var()
    if abs(avg1 - avg2) > delta or abs(var1 - var2) > delta**2:
        return False
    else:
        return True

# %%
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

def describeSeries(data, label):
    fig = plt.gcf()
    fig.set_size_inches(18.5, 10.5)
    plt.plot(data, label = "Series")
    plt.plot(data.rolling(window = 2).mean(), '--', label = "Rolling mean")
    plt.plot(data.rolling(2).std(), ":", label = "Rolling Std")
    plt.legend()
    plt.show()
    plt.savefig(label)
    plt.clf()

# %%
describeSeries(df['SPO2'], "DescribeCO.png")

# %%
def splitTrainTest(series, testSplit):
    totalData = len(series)
    trainSplit = int(totalData * (1 - testSplit))
    trainSet = series[:trainSplit]
    testSet = series[trainSplit:]
    return trainSet, testSet

# %%
isSeriesStationaryAvg(df["SPO2"].values)
# Out:
# True

# %%
isSeriesStationary(df["SPO2"].values)
# Out:
# True

# %%
trainSet, testSet = splitTrainTest(df["SPO2"].values, 0.1)

# %%
import statsmodels.api as sm

# %%
differencedTrainSet = difference(trainSet, 365)
model = sm.tsa.ARIMA(differencedTrainSet, order=(7,0,1))
"""Fit model with non constant trend and no displacement"""
model_fit = model.fit()
forecast = model_fit.predict(len(differencedTrainSet), len(differencedTrainSet) + len(testSet))

# %%
yPrediction = []
history = list(trainSet)
for f in forecast:
    yPredict = inverse_difference(history, f, 365)
    yPrediction.append(yPredict)
    history.append(yPredict)

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(testSet, color='green', label = "Test")
plt.plot(yPrediction[:-1], color='red', label = "Prediction")
plt.legend()
plt.savefig("TemperaturePrediction.png")

# %%
print(sqrt(mean_squared_error(testSet, yPrediction[:-1])))
# Out:
# 0.3993474301468267

# %% [markdown]
# # Random forest

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
from pandas import DataFrame
import numpy as np
from datetime import datetime
import calendar
from datetime import timedelta
import datetime as dt

# %%
df.head()
# Out:
#          CH4            DateTime
# 0   1.000000 2020-05-05 10:25:01
# 24  0.490644 2020-05-05 10:25:26
# 25  0.476540 2020-05-05 10:25:26
# 26  0.467476 2020-05-05 10:25:26
# 27  0.455446 2020-05-05 10:25:26

# %%
df1=df

# %%
df1.head()
# Out:
#          CH4            DateTime
# 0   1.000000 2020-05-05 10:25:01
# 24  0.490644 2020-05-05 10:25:26
# 25  0.476540 2020-05-05 10:25:26
# 26  0.467476 2020-05-05 10:25:26
# 27  0.455446 2020-05-05 10:25:26

# %%
df1['year'] = pd.DatetimeIndex(df1['DateTime']).year
df1['month'] = pd.DatetimeIndex(df1['DateTime']).month
df1['day'] = pd.DatetimeIndex(df1['DateTime']).day
df1['hour'] = pd.DatetimeIndex(df1['DateTime']).hour
df1['minute'] = pd.DatetimeIndex(df1['DateTime']).minute
df1['second'] = pd.DatetimeIndex(df1['DateTime']).second

# %%
df1.head()
# Out:
#          CH4            DateTime  year  month  day  hour  minute  second
# 0   1.000000 2020-05-05 10:25:01  2020      5    5    10      25       1
# 24  0.490644 2020-05-05 10:25:26  2020      5    5    10      25      26
# 25  0.476540 2020-05-05 10:25:26  2020      5    5    10      25      26
# 26  0.467476 2020-05-05 10:25:26  2020      5    5    10      25      26
# 27  0.455446 2020-05-05 10:25:26  2020      5    5    10      25      26

# %%
df.head()
# Out:
#          CH4            DateTime  year  month  day  hour  minute  second
# 0   1.000000 2020-05-05 10:25:01  2020      5    5    10      25       1
# 24  0.490644 2020-05-05 10:25:26  2020      5    5    10      25      26
# 25  0.476540 2020-05-05 10:25:26  2020      5    5    10      25      26
# 26  0.467476 2020-05-05 10:25:26  2020      5    5    10      25      26
# 27  0.455446 2020-05-05 10:25:26  2020      5    5    10      25      26

# %%
df1=df.copy()

# %%
df1.drop(['DateTime'],inplace=True,axis=1)

# %%
df1.head()
# Out:
#          CH4  year  month  day  hour  minute  second
# 0   1.000000  2020      5    5    10      25       1
# 24  0.490644  2020      5    5    10      25      26
# 25  0.476540  2020      5    5    10      25      26
# 26  0.467476  2020      5    5    10      25      26
# 27  0.455446  2020      5    5    10      25      26

# %%
Y=df1['CH4']
X=df1

# %%
print(X.shape)
# Out:
# (53563, 7)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,shuffle=False)

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=1000)
model.fit(x_train, y_train)
yhat = model.predict(x_test)

# %%
y_test
# Out:
# 42365    0.156836
# 42366    0.151694
# 42367    0.154008
# 42368    0.146642
# 42369    0.151694
#            ...
# 53319    0.125460
# 53320    0.122686
# 53321    0.122686
# 53322    0.122686
# 53323    0.124534
# Name: CH4, Length: 13391, dtype: float64

# %%
yhat
# Out:
# array([0.156836  , 0.151694  , 0.154008  , ..., 0.122686  , 0.122686  ,
#        0.12453402])

# %%
plt.figure(figsize=(22,8))
plt.plot(y_test.values, label='Expected')
plt.plot(yhat, label='Predicted')
plt.legend()
plt.show()
